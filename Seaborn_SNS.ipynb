# %%
import pandas
import matplotlib
import scipy
import seaborn as sns
print(sns.get_dataset_names())
#get a list of all datasets that are in-built in Seaborn
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
#Seaborn is mainly used for statistical visualization

#To create plots like:

#regression plots

#distributions

#confidence intervals

#Seaborn needs mathematical and statistical functions

#These functions come from SciPy

# %%
import seaborn as sns
df = sns.load_dataset('diamonds') #Load Data To Construct Seaborn Plots
print(df)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
from matplotlib import pyplot as plt
import seaborn as sns
plt.scatter(df.carat,df.color)
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sns
plt.scatter(df.carat,df.color)
sns.set() #style this plot using the set() function
#sns. set() will load seaborn's default theme and color palette to the session.
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sns
plt.scatter(df.carat,df.color)
#sns.set()
sns.set_style()    #Darkgrid, Whitegrid, Dark, White, Ticks
#set_style() function of Seaborn we can set any of
# the themes available on Seaborn library.
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df1 = sns.load_dataset('car_crashes')
print(df1.head())
plt.scatter(df1.speeding,df1.alcohol)
sns.set_style("whitegrid")
#Set the parameters that control the general style of the plots.
#sns.despine()   #remove the top and right axis spines using the despine() function.
#despine - take away the top and right spines using the sns. despine() function.
# Note: this function must be called after you have called your plot. Not including any spines at all may be an aesthetic decision.
plt.show()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
#Parameters available are viewed using axes_style() function as shown below:
import seaborn as sns
param=sns.axes_style()
param
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': '.8',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.round: 'round'>,
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': False,
#  'xtick.top': False,
#  'ytick.left': False,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df1 = sns.load_dataset('car_crashes')
plt.scatter('speeding','alcohol',data=df1)
sns.set_style("darkgrid", {'grid.color': '0.8'})
#sns.set_style("darkgrid", {'grid.color': '.8'})
#sns.despine()
plt.show()

# %%
#Seaborn allows us to control individual elements of our graphs
#we can control the scale of these elements or the plot by using
#the set_context() function.
#four preset templates for contexts
#paper
#notebook
#talk
#poster

# %%
from matplotlib import pyplot as plt
import seaborn as sns
plt.scatter(df1.speeding,df1.alcohol)
#sns.set_style("dark")
#sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})
sns.set_context("notebook") #By default, context is set to notebook
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sns
plt.scatter(df1.speeding,df1.alcohol)
sns.set_style("dark")
sns.set_context("poster")
plt.show()

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#relplot
#The Seaborn Relational Plot (relplot) allows us to visualise how variables within a dataset relate to each other.
sns.set_context("notebook")
sns.relplot(data=tips, x="total_bill", y="tip")
#relplot() function provides access to several
#different axes-level functions that show the relationship between two variables

#sns.set_context("notebook")   # default – best for Jupyter notebooks
#sns.set_context("paper")      # small – for research papers
#sns.set_context("talk")       # larger – for presentations
#sns.set_context("poster")     # biggest – for posters

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="time", col="day", col_wrap=4)
#hue is used to give Different colors for different values of time column
# Col : Creates separate subplots (columns) for each category in day
# col_wrap=4 : 4 plots

# %%
sns.relplot(data=tips, x="size", y="tip",kind="line", ci=None)
#sns.relplot(data=tips, x="size", y="tip",kind="line")
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
#Point Plot

#Point plots can be more useful than bar plots for focusing comparisons between different
#levels of one or more categorical variables.
# importing required packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("tips")
data
sns.pointplot(x="day", y="tip", data=data)
plt.show()

# %%
sns.pointplot(x="time", y="total_bill", hue="smoker",
                   data=data, palette="Accent")
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
#Joint Plot
#Joint Plot draws a plot of two variables with bivariate and univariate graphs.
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("dark")
tips=sns.load_dataset('tips')
sns.jointplot(x='total_bill', y='tip',data=tips)

# %%
# Add regression line to scatter plot and kernel density estimate to histogram
sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg')  #kind - hex,kde

# %%
#Regplot
#Regplot is one of the functions in Seaborn that are used to visualize the linear relationship as determined through regression.
import seaborn as sns
tips = sns.load_dataset("tips")
ax = sns.regplot(x="total_bill", y="tip", data=tips)

# %%
#A box plot is composed of a summary of 5 different data points:
#the minimum, first quartile, median, third quartile, and maximum.
import seaborn as sns
tips = sns.load_dataset("tips")
sns.boxplot(x="day", y="total_bill", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#The bottom black horizontal line of the box plot is the minimum value
#The first black horizontal line of the rectangle shape of the box plot is the first quartile or 25%
#The second black horizontal line of the rectangle shape of the box plot is Second quartile or 50% or median.
#The third black horizontal line of rectangle shape of the same box plot is third quartile or 75%
#The top black horizontal line of the rectangle shape of the box plot is the maximum value.
#The small diamond shape of the box plot is outlier data.

# %%
#Heatmap
#A heatmap is a two-dimensional graphical representation of data where the individual
# values that are contained in a matrix are represented as colours.
import seaborn as sns
import matplotlib.pyplot as plt

flights = sns.load_dataset("flights")
flights_pivot = flights.pivot(
    index="month",
    columns="year",
    values="passengers"
)
# Print pivot table
print(flights_pivot)

# Plot heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(flights_pivot, cmap="YlGnBu", annot=True, fmt="d")
plt.title("Monthly Airline Passengers Heatmap")
plt.xlabel("Year")
plt.ylabel("Month")
plt.show()
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
car_crashes = sns.load_dataset("car_crashes")

# Select only numeric columns
numeric_data = car_crashes.select_dtypes(include='number')

# Compute correlation matrix
corr = numeric_data.corr()

# Print correlation matrix
print(corr)

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, linewidths=0.5, cmap="YlGnBu")
plt.title("Correlation Heatmap of Car Crashes Dataset")
plt.show()
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000

# %% [markdown]
# The value of the correlation coefficient can take any values from -1 to 1.
#
#     If the value is 1, it is said to be a positive correlation between two variables. This means that when one variable increases, the other variable also increases.
#     If the value is -1, it is said to be a negative correlation between the two variables. This means that when one variable increases, the other variable decreases.
#     If the value is 0, there is no correlation between the two variables. This means that the variables changes in a random manner with respect to each other.

# %%
import seaborn
import matplotlib.pyplot as plt
#To plot multiple pairwise bivariate distributions
#in a dataset, you can use the .pairplot() function.

# loading dataset using seaborn
df = seaborn.load_dataset('tips')
# pairplot with hue day
seaborn.pairplot(df, hue ='day')
 #hue - Variable in “data“ to map plot aspects to different colors.
# to show
plt.show()

# %%
#Sequential Palette : one color only
# libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Create a dataset
df = pd.DataFrame(np.random.random((10,10)), columns=["a","b","c","d","e","f","g","h","i","j"])

# plot using a color palette
sns.heatmap(df, cmap="YlGnBu")
plt.show()

sns.heatmap(df, cmap="Blues")
plt.show()

sns.heatmap(df, cmap="BuPu") #customize the colors in your heatmap with the cmap parameter of the heatmap() function in seaborn.
plt.show()

sns.heatmap(df, cmap="Greens")
plt.show()

# %%
#set maximum and minimum values for color bar on a seaborn heatmap by giving values to vmax and vmin parameters in the function.
# libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Create a dataset
df = pd.DataFrame(np.random.random((10,10)), columns=["a","b","c","d","e","f","g","h","i","j"])

# color bar range between 0 and 0.5
sns.heatmap(df, vmin=0, vmax=0.5)
plt.show()

# color bar range between 0.5 and 0.7
sns.heatmap(df, vmin=0.5, vmax=0.7)
plt.show()

# %%
#To uses 2 contrast colors pink and yellow-green in the heatmap.
# libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# create dataset
df = np.random.randn(30, 30)

# plot heatmap
sns.heatmap(df, cmap="PiYG")
plt.show()

# %%
#When plotting divergant data, you can specify the value at which to center the colormap using center parameter. You can see the following example heatmap for data centered on 1 with a diverging colormap:
# libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# create dataset
df = np.random.randn(30, 30)

# plot heatmap
sns.heatmap(df, center=1)
plt.show()

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.color_palette.html
#
# URL FOR REFERENCE
