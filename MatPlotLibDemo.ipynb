# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([0,20])
y=np.array([0,250])

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,'o')

# %%
x1=np.array([2,13,25,67])
y1=np.array([10,20,85,52])
plt.plot(x1,y1)

# %%
plt.plot(y1,marker='o')

# %%
# Marker Type
#'o' 	Circle 	
#'*' 	Star 	
#'.' 	Point 	
#',' 	Pixel 	
#'x' 	X 	
#'X' 	X (filled) 	
#'+' 	Plus 	
#'P' 	Plus (filled) 	
#'s' 	Square 	
#'D' 	Diamond 	
#'d' 	Diamond (thin) 	
#'p' 	Pentagon 	
#'H' 	Hexagon 	
#'h' 	Hexagon 	
#'v' 	Triangle Down 	
#'^' 	Triangle Up 	
#'<' 	Triangle Left 	
#'>' 	Triangle Right 	
#'1' 	Tri Down 	
#'2' 	Tri Up 	
#'3' 	Tri Left 	
#'4' 	Tri Right 	
#'|' 	Vline 	
#'_' 	Hline

#Line Type
#'-' 	Solid line 	
#':' 	Dotted line 	
#'--' 	Dashed line 	
#'-.' 	Dashed/dotted line

#Colors
#'r' 	Red 	
#'g' 	Green 	
#'b' 	Blue 	
#'c' 	Cyan 	
#'m' 	Magenta 	
#'y' 	Yellow 	
#'k' 	Black 	
#'w' 	White

# %%
plt.plot(x1,y1,marker='*',ms=10,mec='r',mfc='y')

# %%
plt.plot(x1,y1,linestyle='dotted', color='g',linewidth='10')#dashed'--',dashdot'-.',solid'-',none''

# %%
plt.plot(x,y)
plt.plot(x1,y1)

# %%
plt.plot(x,y,x1,y1)
# Out:
# [<matplotlib.lines.Line2D at 0x7fdf136a50d0>,
#  <matplotlib.lines.Line2D at 0x7fdf136a4b50>]

# %%
#plt.plot(x1,y1)
font={'color':'green','size':'20'}
plt.title("line chart",fontdict=font, loc='left')
plt.xlabel("number1")
plt.ylabel("number2")
#plt.show()
plt.plot(x1,y1)
plt.grid(axis='y',color='red',linestyle='--',linewidth='0.5')

# %%
plt.subplot(1,2,1)#one row,2 columns=>subplot(2,1,1)->2row, 1 column=> can have 2 rows 3 columns to display 6 plots in one figure.
plt.title("p1")
plt.plot(x,y)
plt.subplot(1,2,2)
plt.title("p2")
plt.plot(x1,y1)
plt.suptitle("SuperTitle")
# Out:
# Text(0.5, 0.98, 'SuperTitle')

# %%
sizes=np.array([10,50])
plt.scatter(x1,y1,color='red')
plt.scatter(x,y,color='green',s=sizes, alpha=0.5)

# %%
plt.bar(x1,y1)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(x1,y1)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(x1,y1,color='m',width=11)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.hist(x1)
# Out:
# (array([1., 1., 0., 1., 0., 0., 0., 0., 0., 1.]),
#  array([ 2. ,  8.5, 15. , 21.5, 28. , 34.5, 41. , 47.5, 54. , 60.5, 67. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.pie(x1)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fbdcd832410>,
#   <matplotlib.patches.Wedge at 0x7fbdcd85c390>,
#   <matplotlib.patches.Wedge at 0x7fbdcd86a3d0>,
#   <matplotlib.patches.Wedge at 0x7fbdcd86ba90>],
#  [Text(1.0981040361812209, 0.06455637631180881, ''),
#   Text(0.9657984495240577, 0.5265295384847144, ''),
#   Text(-0.04842946277668594, 1.0989333861227266, ''),
#   Text(-0.4246786391308206, -1.0147157500827484, '')])

# %%
track_stud=np.array([20,30,40,20,10])
track_name=["Data","Mobile","Web","IoT","CyberSecurity"]
ex=[0.2,0,0,0,0]
col=["Red","Pink",'m','g','b']
plt.pie(track_stud,labels=track_name,startangle=90,explode=ex,shadow=True,colors=col)
plt.legend(title="Tracks")
plt.show()
